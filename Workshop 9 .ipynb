# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("/Users/chelseabellamy/Downloads/customers_wk9_thurs.csv")
products = pd.read_csv("/Users/chelseabellamy/Downloads/products_wk9_thurs.csv")
sales = pd.read_csv("/Users/chelseabellamy/Downloads/sales_wk9_thurs.csv")

# %%
customers
# Out:
#     customer_id first_name last_name  age state  income registration_date  \
# 0             1       John     Smith   34    CA   75000        2022-01-15
# 1             2      Sarah   Johnson   28    NY   82000        2022-01-22
# 2             3    Michael     Brown   45    TX   95000        2022-02-03
# 3             4      Emily     Davis   31    FL   68000        2022-02-14
# 4             5      David    Wilson   52    IL  110000        2022-02-28
# ..          ...        ...       ...  ...   ...     ...               ...
# 95           96      Alice   Wallace   28    CA   69000        2023-12-08
# 96           97      Henry     Woods   47    NY   98000        2023-12-15
# 97           98    Barbara      Cole   34    TX   79000        2023-12-22
# 98           99     Walter      West   40    FL   87000        2023-12-29
# 99          100      Betty    Jordan   33    IL   76000        2024-01-05
#
#                       email
# 0      john.smith@email.com
# ...

# %%
customers["registration_date"]= pd.to_datetime(customers["registration_date"])
customers
# Out:
#     customer_id first_name last_name  age state  income registration_date  \
# 0             1       John     Smith   34    CA   75000        2022-01-15
# 1             2      Sarah   Johnson   28    NY   82000        2022-01-22
# 2             3    Michael     Brown   45    TX   95000        2022-02-03
# 3             4      Emily     Davis   31    FL   68000        2022-02-14
# 4             5      David    Wilson   52    IL  110000        2022-02-28
# ..          ...        ...       ...  ...   ...     ...               ...
# 95           96      Alice   Wallace   28    CA   69000        2023-12-08
# 96           97      Henry     Woods   47    NY   98000        2023-12-15
# 97           98    Barbara      Cole   34    TX   79000        2023-12-22
# 98           99     Walter      West   40    FL   87000        2023-12-29
# 99          100      Betty    Jordan   33    IL   76000        2024-01-05
#
#                       email
# 0      john.smith@email.com
# ...

# %%
sales
# Out:
#      sale_id  customer_id  product_id     transaction_date  quantity  \
# 0          1            1           1  2022-02-10 14:30:00         1
# 1          2            2           3  2022-02-15 10:15:00         2
# 2          3            3           5  2022-02-20 16:45:00         1
# 3          4            4           2  2022-02-25 11:20:00         3
# 4          5            5           4  2022-03-01 13:10:00         1
# ..       ...          ...         ...                  ...       ...
# 145      146           86          30  2024-02-15 15:20:00         1
# 146      147           87          32  2024-02-20 11:30:00         3
# 147      148           88          34  2024-02-25 13:45:00         2
# 148      149           89          36  2024-03-01 16:15:00         1
# 149      150           90          38  2024-03-05 10:30:00         4
#
#      total_amount
# 0           79.99
# 1           39.98
# 2           34.99
# 3           74.97
# 4           89.99
# ..            ...
# ...

# %%
sales["transaction_date"] = pd.to_datetime(sales["transaction_date"])
sales
# Out:
#      sale_id  customer_id  product_id    transaction_date  quantity  \
# 0          1            1           1 2022-02-10 14:30:00         1
# 1          2            2           3 2022-02-15 10:15:00         2
# 2          3            3           5 2022-02-20 16:45:00         1
# 3          4            4           2 2022-02-25 11:20:00         3
# 4          5            5           4 2022-03-01 13:10:00         1
# ..       ...          ...         ...                 ...       ...
# 145      146           86          30 2024-02-15 15:20:00         1
# 146      147           87          32 2024-02-20 11:30:00         3
# 147      148           88          34 2024-02-25 13:45:00         2
# 148      149           89          36 2024-03-01 16:15:00         1
# 149      150           90          38 2024-03-05 10:30:00         4
#
#      total_amount
# 0           79.99
# 1           39.98
# 2           34.99
# 3           74.97
# 4           89.99
# ..            ...
# ...

# %%
products
# Out:
#     product_id                   product_name           category   price  \
# 0            1  Wireless Bluetooth Headphones        Electronics   79.99
# 1            2         Organic Cotton T-Shirt           Clothing   24.99
# 2            3   Stainless Steel Water Bottle      Home & Garden   19.99
# 3            4          Leather Crossbody Bag        Accessories   89.99
# 4            5               Yoga Mat Premium  Sports & Outdoors   34.99
# 5            6          Smart Fitness Tracker        Electronics  149.99
# 6            7         Ceramic Coffee Mug Set      Home & Garden   29.99
# 7            8           Denim Jacket Classic           Clothing   69.99
# 8            9         Wireless Phone Charger        Electronics   39.99
# 9           10            Silk Scarf Designer        Accessories   54.99
# 10          11      Running Shoes Performance  Sports & Outdoors  119.99
# 11          12         Indoor Plant Succulent      Home & Garden   12.99
# ...

# %%
products["launch_date"] = pd.to_datetime(products["launch_date"])
products
# Out:
#     product_id                   product_name           category   price  \
# 0            1  Wireless Bluetooth Headphones        Electronics   79.99
# 1            2         Organic Cotton T-Shirt           Clothing   24.99
# 2            3   Stainless Steel Water Bottle      Home & Garden   19.99
# 3            4          Leather Crossbody Bag        Accessories   89.99
# 4            5               Yoga Mat Premium  Sports & Outdoors   34.99
# 5            6          Smart Fitness Tracker        Electronics  149.99
# 6            7         Ceramic Coffee Mug Set      Home & Garden   29.99
# 7            8           Denim Jacket Classic           Clothing   69.99
# 8            9         Wireless Phone Charger        Electronics   39.99
# 9           10            Silk Scarf Designer        Accessories   54.99
# 10          11      Running Shoes Performance  Sports & Outdoors  119.99
# 11          12         Indoor Plant Succulent      Home & Garden   12.99
# ...

# %%
sales['sales_year'] = sales["transaction_date"].dt.year
sales['sales_month'] = sales["transaction_date"].dt.month_name()
sales['sales_day_of_week'] = sales["transaction_date"].dt.day_name()
sales.head(10)
# Out:
#    sale_id  customer_id  product_id    transaction_date  quantity  \
# 0        1            1           1 2022-02-10 14:30:00         1
# 1        2            2           3 2022-02-15 10:15:00         2
# 2        3            3           5 2022-02-20 16:45:00         1
# 3        4            4           2 2022-02-25 11:20:00         3
# 4        5            5           4 2022-03-01 13:10:00         1
# 5        6            6           7 2022-03-05 09:30:00         2
# 6        7            7           6 2022-03-10 15:20:00         1
# 7        8            8           8 2022-03-15 12:45:00         1
# 8        9            9           9 2022-03-20 14:15:00         2
# 9       10           10          10 2022-03-25 16:30:00         1
#
#    total_amount  sales_year sales_month sales_day_of_week
# 0         79.99        2022    February          Thursday
# 1         39.98        2022    February           Tuesday
# 2         34.99        2022    February            Sunday
# ...

# %%
products["year_of_launch"] = products["launch_date"].dt.year
products["month_of_launch"] = products["launch_date"].dt.month_name()
products["day_of_launch"] = products["launch_date"].dt.day_name()
products.head(10)
# Out:
#    product_id                   product_name           category   price  \
# 0           1  Wireless Bluetooth Headphones        Electronics   79.99
# 1           2         Organic Cotton T-Shirt           Clothing   24.99
# 2           3   Stainless Steel Water Bottle      Home & Garden   19.99
# 3           4          Leather Crossbody Bag        Accessories   89.99
# 4           5               Yoga Mat Premium  Sports & Outdoors   34.99
# 5           6          Smart Fitness Tracker        Electronics  149.99
# 6           7         Ceramic Coffee Mug Set      Home & Garden   29.99
# 7           8           Denim Jacket Classic           Clothing   69.99
# 8           9         Wireless Phone Charger        Electronics   39.99
# 9          10            Silk Scarf Designer        Accessories   54.99
#
#   launch_date        brand  year_of_launch month_of_launch day_of_launch
# 0  2021-03-15    AudioTech            2021           March        Monday
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       60 non-null     int64
#  1   product_name     60 non-null     object
#  2   category         60 non-null     object
#  3   price            60 non-null     float64
#  4   launch_date      60 non-null     datetime64[ns]
#  5   brand            60 non-null     object
#  6   year_of_launch   60 non-null     int32
#  7   month_of_launch  60 non-null     object
#  8   day_of_launch    60 non-null     object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(5)
# memory usage: 4.1+ KB

# %%
#1.1c Display Date ranges from Sales Data 
min_date= (sales["transaction_date"].min())
print("Min_date", "=" , min_date)
Max_Date = (sales["transaction_date"].max())
print("Max_Date", "=", Max_Date)
# Out:
# Min_date = 2022-02-10 14:30:00
# Max_Date = 2024-03-05 10:30:00

# %%
# 1.2a Find the busiest day of the week for sales (by counting transactions)
sales['sales_day_of_week'].value_counts().head(1)
# Out:
# sales_day_of_week
# Friday    24
# Name: count, dtype: int64

# %%
#1.2b Determine which month had the most transactions
sales['sales_month'].value_counts().head(1)
# Out:
# sales_month
# February    16
# Name: count, dtype: int64

# %%
#Find the most expensive product in each category
#Count how many products are in each category ???

# %%
products["month_of_launch"].value_counts().head(1)
# Out:
# month_of_launch
# June    8
# Name: count, dtype: int64

# %%
#1.2c Count how many sales happened in each year
sales['sales_year'].value_counts().sort_index()
# Out:
# sales_year
# 2022    65
# 2023    72
# 2024    13
# Name: count, dtype: int64

# %%
#Product Analysis: 2. 1a
#Group products by category and calculate the average price for each category
products.groupby('category').max()
# Out:
#                    product_id            product_name   price launch_date  \
# category
# Accessories                60      Watch Band Leather   89.99  2023-06-27
# Clothing                   59       Wool Sweater Knit   99.99  2023-06-14
# Electronics                58  Wireless Phone Charger  149.99  2023-06-01
# Home & Garden              57       Wall Clock Modern   49.99  2023-05-19
# Sports & Outdoors          56        Yoga Mat Premium  249.99  2023-05-06
#
#                          brand  year_of_launch month_of_launch day_of_launch
# category
# Accessories          ToolCraft            2023       September     Wednesday
# Clothing            UrbanStyle            2023       September     Wednesday
# Electronics          VideoTech            2023       September     Wednesday
# Home & Garden         TimeKeep            2023       September     Wednesday
# Sports & Outdoors  TrailMaster            2023       September       Tuesday

# %%
#2.1b Count how many products are in each category
products.groupby('category').value_counts()
# Out:
# category           product_id  product_name                   price   launch_date  brand          year_of_launch  month_of_launch  day_of_launch
# Accessories        4           Leather Crossbody Bag          89.99   2021-06-01   StyleCraft     2021            June             Tuesday          1
#                    10          Silk Scarf Designer            54.99   2021-09-02   LuxeFashion    2021            September        Thursday         1
#                    15          Sunglasses Polarized           45.99   2021-11-12   SunShield      2021            November         Friday           1
#                    20          Watch Band Leather             19.99   2022-01-20   TimeStyle      2022            January          Thursday         1
#                    25          Baseball Cap Vintage           22.99   2022-03-28   RetroStyle     2022            March            Monday           1
# ...

# %%
#2 Customer Analysis: 2.1a Group customers by state and find the average age in each state
customers.groupby('state')['age'].mean().round()
# Out:
# state
# CA    34.0
# FL    39.0
# IL    37.0
# NY    36.0
# TX    38.0
# Name: age, dtype: float64

# %%
#2.2 b #Calculate total spending per customer (sum up all their purchases)
sales.groupby('customer_id')['total_amount'].sum()
# Out:
# customer_id
# 1     229.98
# 2     179.96
# 3     154.98
# 4     234.95
# 5     149.98
#        ...
# 86     34.99
# 87     83.97
# 88    109.98
# 89     29.99
# 90    139.96
# Name: total_amount, Length: 90, dtype: float64

# %%
#2.2c #Find customers who have made the most purchases
sales.groupby('customer_id').size().sort_values(ascending=False)
# Out:
# customer_id
# 57    2
# 58    2
# 59    2
# 60    2
# 9     2
#      ..
# 78    1
# 79    1
# 80    1
# 89    1
# 90    1
# Length: 90, dtype: int64

# %%
# Sales Analysis: 2.3 a Calculate total sales revenue by month
sales.groupby('sales_month')['total_amount'].sum()
#Determine which product category generates the most total revenue
# Out:
# sales_month
# April         924.77
# August        870.74
# December     1458.71
# February     1669.66
# January       864.79
# July          930.80
# June          986.68
# March        1115.77
# May          1177.79
# November     1022.76
# October      1235.80
# September    1150.76
# Name: total_amount, dtype: float64

# %%
#Find the average transaction amount by day of the week
sales.groupby('sales_day_of_week')['quantity'].mean().round()
# Out:
# sales_day_of_week
# Friday       2.0
# Monday       2.0
# Saturday     2.0
# Sunday       2.0
# Thursday     2.0
# Tuesday      2.0
# Wednesday    2.0
# Name: quantity, dtype: float64

# %%
#Determine which product category generates the most total revenue
products.groupby('category')['price'].sum()
# Out:
# category
# Accessories           420.88
# Clothing              626.88
# Electronics           779.87
# Home & Garden         361.88
# Sports & Outdoors    1164.89
# Name: price, dtype: float64

# %%
#Simple Comparisons:3.1 Find which state has the most customers
# Count unique customers by state
customers.groupby('state')['customer_id'].nunique() 

#Determine which day of the week has the highest average transaction value
# Out:
# state
# CA    20
# FL    20
# IL    20
# NY    20
# TX    20
# Name: customer_id, dtype: int64

# %%
#Simple Comparisons:3.2
#Identify the top 5 customers by total spending

total_spending= sales.groupby('customer_id')['total_amount'].sum()
top_5_customers = total_spending.sort_values(ascending=False).head(5)
print("Top 5 customers by total spending:")
print(top_5_customers)
# Out:
# Top 5 customers by total spending:
# customer_id
# 31    379.97
# 13    359.96
# 41    329.98
# 84    319.98
# 30    284.98
# Name: total_amount, dtype: float64

# %%
#Simple Comparisons:3.2
#Determine which day of the week has the highest average transaction value

avgerage_sales_transaction_by_day = sales.groupby('sales_day_of_week')['total_amount'].mean()
avgerage_sales_transaction_by_day.max()
avgerage_sales_transaction_by_day.sort_index()
# Out:
# sales_day_of_week
# Friday       100.940833
# Monday        90.927500
# Saturday      61.121905
# Sunday        99.551429
# Thursday     102.267619
# Tuesday       74.028636
# Wednesday     96.071905
# Name: total_amount, dtype: float64
